# %%
# pip install transformers sentencepiece
import torch
from transformers import AutoTokenizer, AutoModel
import numpy as np
from numpy import dot
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd


tokenizer = AutoTokenizer.from_pretrained("cointegrated/rubert-tiny2")
model = AutoModel.from_pretrained("cointegrated/rubert-tiny2")


tokenizer = AutoTokenizer.from_pretrained("DeepPavlov/rubert-base-cased-sentence")
model = AutoModel.from_pretrained("DeepPavlov/rubert-base-cased-sentence")
# model.cuda()  # uncomment it if you have a GPU

def embed_bert(text, model, tokenizer):
    t = tokenizer(text, padding=True, truncation=True, return_tensors='pt')
    with torch.no_grad():
        model_output = model(**{k: v.to(model.device) for k, v in t.items()})
    embeddings = model_output.last_hidden_state[:, 0, :]  # вектор токена [CLS], который является агрегированной информацией о всём тексте
    #embeddings = model_output.pooler_output
    embeddings = torch.nn.functional.normalize(embeddings)
    return embeddings[0].cpu().numpy()

# print(embed_bert_cls('привет мир', model, tokenizer))
# (312,)
# Out:
# /home/kolya/venv/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/711M [00:00<?, ?B/s]

# %%
def cos_distance(e1, e2):
    return 1 - dot(e1, e2)/np.linalg.norm(e1)/np.linalg.norm(e2)

class Retrieval:
    def __init__(self, chunks, model, tokenizer):
        if isinstance(chunks, pd.DataFrame):
            self.chunks = list(chunks["chunks"])
        elif isinstance(chunks, list):
            self.chunks = chunks
        else:
            raise TypeError('чанки должны быть или списком или датафреймом')
        self.model = model
        self.tokenizer = tokenizer
        self.chunk_vecs = []
        for chunk in self.chunks:
            self.chunk_vecs.append(list(embed_bert(chunk, model, tokenizer)))
        self.chunk_vecs = np.array(self.chunk_vecs)

    def find_context(self, question):
        q_emb = embed_bert(question, self.model, self.tokenizer)
        min_ind = 0
        distances = []
        for i in range(len(self.chunks)):
            distances.append(cos_distance(q_emb, self.chunk_vecs[i]))
        min_ind = np.argmin(distances)

        return self.chunks[min_ind], distances[min_ind], min_ind, distances

    def find_top_k_context(self, question, k):
        q_emb = embed_bert(question, self.model, self.tokenizer)
        min_ind = 0
        distances = []
        for i in range(len(self.chunks)):
            distances.append((cos_distance(q_emb, self.chunk_vecs[i]), i))

        distances.sort(reverse = False, key = lambda x: x[0])
        distances = distances[:k]
        indexes = list(map(lambda x: x[1], distances))
        dist = list(map(lambda x: x[0], distances))
        return indexes, dist

# %%
df = pd.read_csv('chunks.csv')
retr = Retrieval(df, model, tokenizer)
df
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
#                                                chunks  \
# 0   Кафедра ФН-11 осуществляет подготовку бакалавр...
# 1   В 1878г. заведующим кафедрой общей и прикладно...
# 2   Главный учебный корпус (ГУК) МГТУ состоит из д...
# 3   Сообщение между подразделениями университета о...
# 4   Учебно-лабораторный корпус был открыт 1 марта ...
# ..                                                ...
# 69  Общежитие №5 Адрес: 105043, Москва, Измайловск...
# 70  информация доступна на странице Общежитие №5. ...
# 71  Почтовые отделения Измайловское Адрес отделени...
# 72  - 18:00 ВС выходной Банковские отделения Сберб...
# 73  ул. Парковая 5-я, 30а (на карте) График работы...
#
#                                             questions  \
# 0   Какие образовательные профили подготовки реали...
# 1   Какие научные достижения были у профессора П.А...
# 2   Из каких частей состоит главный учебный корпус...
# 3   Как устроено сообщение между подразделениями и...
# 4   Когда был открыт учебно-лабораторный корпус (У...
# ..                                                ...
# 69  Где находится общежитие №5 и как связаться с к...
# 70                    Где находится общежитие № 10?\n
# 71  Какой график работы у почтового отделения в Из...
# 72  Какой график работы у военкомата в Измайлово и...
# 73  Какой график работы у военкомата на 5-й Парков...
#
#                                               answers
# 0   Кафедра ФН-11 реализует следующие образователь...
# 1   Профессор П.А. Зилов:  В 1877 году измерил диэ...
# 2   Главный учебный корпус МГТУ состоит из двух ча...
# 3   Сообщение между подразделениями университета о...
# 4   Учебно-лабораторный корпус (УЛК) был открыт 1 ...
# ..                                                ...
# 69  \nОбщежитие №5 расположено по адресу: Москва, ...
# 70              \nМосква, Госпитальный переулок, 4/6.
# 71  \nГрафик работы: с понедельника — 08:00–20:00,...
# 72  \nВоенкомат в Измайлово работает с понедельник...
# 73  \nВоенкомат на ул. 5-я Парковая, д. 30а работа...
#
# [74 rows x 3 columns]

# %%
corr_arr = []
for i in range(len(df)):
    print(f'Номер найденного чанка: {retr.find_top_k_context(df.questions.loc[i], 5)[0]}; Номер вопроса соответствующего чанка: {i}')
# Out:
# Номер найденного чанка: [0, 6, 21, 17, 12]; Номер вопроса соответствующего чанка: 0
# Номер найденного чанка: [27, 17, 37, 41, 31]; Номер вопроса соответствующего чанка: 1
# Номер найденного чанка: [27, 17, 41, 12, 21]; Номер вопроса соответствующего чанка: 2
# Номер найденного чанка: [13, 33, 12, 37, 34]; Номер вопроса соответствующего чанка: 3
# Номер найденного чанка: [14, 4, 12, 17, 53]; Номер вопроса соответствующего чанка: 4
# Номер найденного чанка: [27, 10, 37, 17, 35]; Номер вопроса соответствующего чанка: 5
# Номер найденного чанка: [17, 8, 12, 6, 41]; Номер вопроса соответствующего чанка: 6
# Номер найденного чанка: [10, 7, 27, 17, 12]; Номер вопроса соответствующего чанка: 7
# Номер найденного чанка: [17, 10, 37, 41, 28]; Номер вопроса соответствующего чанка: 8
# Номер найденного чанка: [41, 18, 17, 10, 37]; Номер вопроса соответствующего чанка: 9
# Номер найденного чанка: [38, 56, 28, 45, 41]; Номер вопроса соответствующего чанка: 10
# Номер найденного чанка: [11, 25, 24, 73, 49]; Номер вопроса соответствующего чанка: 11
# Номер найденного чанка: [12, 17, 8, 41, 33]; Номер вопроса соответствующего чанка: 12
# Номер найденного чанка: [37, 17, 41, 27, 10]; Номер вопроса соответствующего чанка: 13
# Номер найденного чанка: [13, 14, 6, 8, 3]; Номер вопроса соответствующего чанка: 14
# Номер найденного чанка: [10, 28, 29, 35, 27]; Номер вопроса соответствующего чанка: 15
# Номер найденного чанка: [16, 34, 41, 18, 37]; Номер вопроса соответствующего чанка: 16
# Номер найденного чанка: [17, 41, 10, 27, 37]; Номер вопроса соответствующего чанка: 17
# Номер найденного чанка: [18, 10, 17, 37, 41]; Номер вопроса соответствующего чанка: 18
# Номер найденного чанка: [41, 17, 12, 8, 10]; Номер вопроса соответствующего чанка: 19
# Номер найденного чанка: [19, 20, 11, 18, 24]; Номер вопроса соответствующего чанка: 20
# Номер найденного чанка: [21, 10, 31, 27, 0]; Номер вопроса соответствующего чанка: 21
# Номер найденного чанка: [18, 34, 37, 31, 33]; Номер вопроса соответствующего чанка: 22
# Номер найденного чанка: [27, 10, 44, 37, 28]; Номер вопроса соответствующего чанка: 23
# Номер найденного чанка: [11, 18, 56, 19, 54]; Номер вопроса соответствующего чанка: 24
# Номер найденного чанка: [28, 41, 27, 17, 21]; Номер вопроса соответствующего чанка: 25
# Номер найденного чанка: [18, 24, 38, 56, 54]; Номер вопроса соответствующего чанка: 26
# Номер найденного чанка: [27, 10, 17, 35, 29]; Номер вопроса соответствующего чанка: 27
# Номер найденного чанка: [28, 38, 27, 10, 7]; Номер вопроса соответствующего чанка: 28
# Номер найденного чанка: [29, 35, 27, 37, 10]; Номер вопроса соответствующего чанка: 29
# Номер найденного чанка: [30, 23, 0, 27, 5]; Номер вопроса соответствующего чанка: 30
# Номер найденного чанка: [17, 27, 10, 41, 37]; Номер вопроса соответствующего чанка: 31
# Номер найденного чанка: [10, 27, 18, 17, 41]; Номер вопроса соответствующего чанка: 32
# Номер найденного чанка: [18, 41, 37, 17, 10]; Номер вопроса соответствующего чанка: 33
# Номер найденного чанка: [18, 34, 17, 37, 10]; Номер вопроса соответствующего чанка: 34
# Номер найденного чанка: [35, 37, 29, 27, 10]; Номер вопроса соответствующего чанка: 35
# Номер найденного чанка: [44, 10, 27, 46, 31]; Номер вопроса соответствующего чанка: 36
# Номер найденного чанка: [35, 37, 27, 10, 29]; Номер вопроса соответствующего чанка: 37
# Номер найденного чанка: [28, 29, 38, 10, 44]; Номер вопроса соответствующего чанка: 38
# Номер найденного чанка: [35, 31, 37, 17, 10]; Номер вопроса соответствующего чанка: 39
# Номер найденного чанка: [36, 40, 39, 44, 27]; Номер вопроса соответствующего чанка: 40
# Номер найденного чанка: [41, 17, 12, 8, 27]; Номер вопроса соответствующего чанка: 41
# Номер найденного чанка: [46, 17, 37, 33, 41]; Номер вопроса соответствующего чанка: 42
# Номер найденного чанка: [43, 46, 44, 45, 10]; Номер вопроса соответствующего чанка: 43
# Номер найденного чанка: [28, 38, 37, 27, 10]; Номер вопроса соответствующего чанка: 44
# Номер найденного чанка: [11, 24, 25, 45, 73]; Номер вопроса соответствующего чанка: 45
# Номер найденного чанка: [46, 44, 35, 27, 10]; Номер вопроса соответствующего чанка: 46
# Номер найденного чанка: [33, 34, 26, 12, 18]; Номер вопроса соответствующего чанка: 47
# Номер найденного чанка: [18, 10, 37, 33, 41]; Номер вопроса соответствующего чанка: 48
# Номер найденного чанка: [46, 10, 44, 37, 35]; Номер вопроса соответствующего чанка: 49
# Номер найденного чанка: [18, 34, 12, 41, 33]; Номер вопроса соответствующего чанка: 50
# Номер найденного чанка: [51, 55, 52, 50, 70]; Номер вопроса соответствующего чанка: 51
# Номер найденного чанка: [37, 41, 28, 18, 17]; Номер вопроса соответствующего чанка: 52
# Номер найденного чанка: [53, 41, 61, 50, 12]; Номер вопроса соответствующего чанка: 53
# Номер найденного чанка: [12, 41, 17, 8, 37]; Номер вопроса соответствующего чанка: 54
# Номер найденного чанка: [28, 38, 54, 55, 27]; Номер вопроса соответствующего чанка: 55
# Номер найденного чанка: [46, 18, 45, 10, 41]; Номер вопроса соответствующего чанка: 56
# Номер найденного чанка: [33, 34, 46, 37, 18]; Номер вопроса соответствующего чанка: 57
# Номер найденного чанка: [33, 37, 34, 46, 18]; Номер вопроса соответствующего чанка: 58
# Номер найденного чанка: [34, 59, 58, 13, 60]; Номер вопроса соответствующего чанка: 59
# Номер найденного чанка: [34, 10, 18, 41, 33]; Номер вопроса соответствующего чанка: 60
# Номер найденного чанка: [61, 6, 41, 0, 33]; Номер вопроса соответствующего чанка: 61
# Номер найденного чанка: [6, 34, 7, 13, 21]; Номер вопроса соответствующего чанка: 62
# Номер найденного чанка: [0, 6, 41, 61, 8]; Номер вопроса соответствующего чанка: 63
# Номер найденного чанка: [18, 12, 70, 50, 34]; Номер вопроса соответствующего чанка: 64
# Номер найденного чанка: [61, 58, 68, 70, 67]; Номер вопроса соответствующего чанка: 65
# Номер найденного чанка: [73, 64, 41, 70, 16]; Номер вопроса соответствующего чанка: 66
# Номер найденного чанка: [18, 34, 41, 16, 37]; Номер вопроса соответствующего чанка: 67
# Номер найденного чанка: [34, 33, 58, 41, 64]; Номер вопроса соответствующего чанка: 68
# Номер найденного чанка: [34, 33, 18, 41, 64]; Номер вопроса соответствующего чанка: 69
# Номер найденного чанка: [41, 53, 64, 56, 73]; Номер вопроса соответствующего чанка: 70
# Номер найденного чанка: [70, 71, 69, 68, 64]; Номер вопроса соответствующего чанка: 71
# Номер найденного чанка: [33, 57, 34, 41, 18]; Номер вопроса соответствующего чанка: 72
# Номер найденного чанка: [70, 73, 57, 50, 64]; Номер вопроса соответствующего чанка: 73

# %%
def recall_at_k(indices, relevant_index, k):
    """
    Вычисляет Recall@k
    :param indices: отсортированный список индексов (сортировка по убыванию релевантности)
    :param relevant_index: индекс релевантного документа
    :param k: топ-k
    :return: Recall@k
    """
    # Проверяем, сколько релевантных документов в топ-k
    relevant_found = sum(1 for idx in indices[:k] if idx == relevant_index)
    return relevant_found / 1  # Всего один релевантный документ для каждого запроса

def mrr(indices, relevant_index):
    """
    Вычисляет Mean Reciprocal Rank (MRR)
    :param indices: отсортированный список индексов (сортировка по убыванию релевантности)
    :param relevant_index: индекс релевантного документа
    :return: MRR
    """
    # Находим позицию первого релевантного документа
    for rank, idx in enumerate(indices, start=1):
        if idx == relevant_index:
            return 1 / rank
    return 0  # Если релевантный документ не найден

def mr(indices, relevant_index):
    """
    Вычисляет Mean Reciprocal Rank (MRR)
    :param indices: отсортированный список индексов (сортировка по убыванию релевантности)
    :param relevant_index: индекс релевантного документа
    :return: MRR
    """
    # Находим позицию первого релевантного документа
    for rank, idx in enumerate(indices, start=1):
        if idx == relevant_index:
            return rank
    return 0  # Если релевантный документ не найден


def ndcg_at_k(indices, relevant_index, k):
    """
    Вычисляет NDCG@k
    :param indices: отсортированный список индексов (сортировка по убыванию релевантности)
    :param relevant_index: индекс релевантного документа
    :param k: топ-k
    :return: NDCG@k
    """
    # Вычисляем DCG@k
    dcg_k = sum(1 / np.log2(i + 1) for i, idx in enumerate(indices[:k], start=1) if idx == relevant_index)
    
    # Вычисляем IDCG@k (идеальный случай, когда релевантный чанк на первом месте)
    idcg_k = 1 / np.log2(2) if relevant_index in indices[:k] else 0
    
    return dcg_k / idcg_k if idcg_k > 0 else 0

# %%
r1 = []
r3 = []
r5 = []
mrr_metrics = []
mean_rank = []
ndcg1 = []
ndcg3 = []
ndcg5 = []

for i in range(len(df)):
    ind = retr.find_top_k_context(df.questions.loc[i], len(df))[0]
    r1.append(recall_at_k(ind, i, 1))
    r3.append(recall_at_k(ind, i, 3))
    r5.append(recall_at_k(ind, i, 5))
    mrr_metrics.append(mrr(ind, i))
    mean_rank.append(mr(ind,i))
    ndcg1.append(ndcg_at_k(ind, i, 1))
    ndcg3.append(ndcg_at_k(ind, i, 3))
    ndcg5.append(ndcg_at_k(ind, i, 5))


# Вычисляем средние значения
avg_r1 = np.mean(r1)
avg_r3 = np.mean(r3)
avg_r5 = np.mean(r5)
avg_mrr = np.mean(mrr_metrics)
avg_mr = np.mean(mean_rank)
avg_ndcg1 = np.mean(ndcg1)
avg_ndcg3 = np.mean(ndcg3)
avg_ndcg5 = np.mean(ndcg5)

# Выводим средние значения
print(f"Average Recall@1: {avg_r1:.3f}")
print(f"Average Recall@3: {avg_r3:.3f}")
print(f"Average Recall@5: {avg_r5:.3f}")
print(f"Average MRR: {avg_mrr:.3f}")
print(f"Average Mean Rank: {avg_mr:.3f}")
print(f"Average NDCG@1: {avg_ndcg1:.3f}")
print(f"Average NDCG@3: {avg_ndcg3:.3f}")
print(f"Average NDCG@5: {avg_ndcg5:.3f}")
# Out:
# Average Recall@1: 0.243
# Average Recall@3: 0.392
# Average Recall@5: 0.432
# Average MRR: 0.366
# Average Mean Rank: 14.378
# Average NDCG@1: 0.243
# Average NDCG@3: 0.335
# Average NDCG@5: 0.353

# %%
mean_rank
# Out:
# [1,
#  1,
#  1,
#  4,
#  6,
#  4,
#  5,
#  1,
#  18,
#  1,
#  25,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  1,
#  1,
#  1,
#  1,
#  1,
#  13,
#  1,
#  1,
#  1,
#  1,
#  2,
#  9,
#  1,
#  1,
#  6,
#  3,
#  1,
#  1,
#  9,
#  2,
#  1,
#  3,
#  3,
#  3,
#  1,
#  1,
#  2,
#  2,
#  21,
#  26,
#  7,
#  7,
#  9,
#  14,
#  1,
#  31,
#  48,
#  29,
#  3,
#  4,
#  1,
#  15,
#  1,
#  13,
#  3,
#  6,
#  16,
#  22,
#  14,
#  9,
#  1,
#  4,
#  1]

# %%
test_ind = 58

print(df.questions.loc[test_ind])
# Out:
# Где и когда студентам нужно визировать анкету для оформления загранпаспорта?

# %%
print(df.chunks.loc[test_ind])
# Out:
# ЧТ ПТ СБ выходной ВС Третий отдел ГЗ, 2 этаж, кабинет 235. С 11 мая 2010 года студенты всех факультетов визируют анкету для оформления загранпаспорта в комнате 396б (центральная лестница, 3 этаж). График работы: День Время работы Обед ПН 13:30 - 17:00 - ВТ СР ЧТ ПТ СБ выходной ВС Интернеты Выдача логинов и паролей на университетский WiFi и на интернет во 2 общежитии осуществляется на первом этаже ГЗ, в том же помещении, что и типография. Сотрудникам (не студентам) интернеты выдаются на 2 этаже

# %%
retr.find_context(df.questions.loc[test_ind])[0]
# Out:
# 'После поступления на курс ты получишь доступ к закрытым вакансиям, сможешь подать заявку и пройти собеседование.'

# %%
ind = retr.find_top_k_context(input(), 5)[0]

for i in ind:
    print(retr.chunks[i])
    print()
# Out:
#  какой точный размер стипендии?
# Да. На некоторых курсах предъявляются особые требования к характеристикам ноутбука. Например, чтобы заняться разработкой на IOS, нужен макбук.
#
# При соответствии критериям получения стипендии, студент программы от VK будет автоматически внесен в список стипендиатов.Если для оформления стипендии что-то потребуется - к студенту обратится напрямую представитель вуза или VK.
#
# Получение стипендии от компании VK не зависит от того, обучается студент в вузе на бюджетной или платной форме обучения.Стипендия суммируется с академической стипендией, начисляемой вузом.
#
# Обычно от четырёх академических часов в неделю без учёта времени на домашние задания. Но нагрузка на каждой программе может быть разной. .
#
# После поступления на курс ты получишь доступ к закрытым вакансиям, сможешь подать заявку и пройти собеседование.

# %%
list(df.chunks)
# Out:
# ['Кафедра ФН-11 осуществляет подготовку бакалавров и магистров по направлению "Математика и компьютерные науки (02.03.01; 02.04.01), реализуя образовательные профили подготовки:\n- Математическое и компьютерное моделирование,\n- Математическое и компьютерное моделирование в экономике,\n- Суперкомпьютерное моделирование и искусственный интеллект в инженерных задачах,\n- Математическое и компьютерное моделирование в механике композитов.',
#  'В 1878г. заведующим кафедрой общей и прикладной физики стал выпускник Московского университета ученик выдающегося русского физика А.Г.Столетова профессор П.А.Зилов. Профессор П.А.Зилов был первым, кто измерил диэлектрические проницаемости некоторых жидких диэлектриков и доказал правильность соотношения между диэлектрической проницаемостью и показателем преломления (1877г.). В 1879г. П.А.Зилов установил зависимость магнитной проницаемости жидкостей от напряженности магнитного поля.  С декабря 1884г. по август 1886г. кафедрой заведовал профессор Н.П.Слугинов, доктор физики С.-Петербургского университета. В 1881г. получил степень магистра физики за диссертацию “Теория электролиза”, в которой он сделал замечательное техническое открытие - способ покрытия алюминия тонким непрерывным слоем кристаллизированного глинозёма, имеющего твёрдость корунда. В 1884г. Н.П.Слугинов защитил докторскую диссертацию на тему “Электрическое свечение” и в том же году перешёл на кафедру физики ИМТУ.',
#  'После поступления на курс ты получишь доступ к закрытым вакансиям, сможешь подать заявку и пройти собеседование.',
#  'Быть студентом 2-6 курсов бакалавриата , специалитета или  магистратуры МГТУ им. Н. Э. Баумана. Есть несколько дополнительных условий:- как показывает практика, студенты второго высшего образования не тянут дополнительную нагрузку в виде обучения в проекте, так как время занятий совпадает с вузовским;- студентам последнего года обучения предъявляют повышенные требования к уровню навыков и знаний на отборе.Посещение занятий студентами, не прошедшими отбор, невозможно. Есть исключения для сотрудников VK, которые проходят некоторые курсы в рамках программы повышения квалификации от компании.Если студент заканчивает вуз на 1-2 семестра раньше окончания основной программы ОЦ, то ему оформляют пропуск для посещения занятий ( это правило относится только к основной программе проекта).',
#  'Учёба в вузе всегда приоритетнее, а Центр работает в  формате дополнительного образования. Если студент не выполняет необходимые требования для перехода на следующий семестр - сдать на положительную оценку все курсы семестра, то он отчисляется. При этом можно снова поступать в ОЦ на общих основаниях вне зависимости от семестра, на котором произошло отчисление из проекта.',
#  'Интересоваться программированием, самостоятельно готовиться и учиться решать задачи. Если студент имеет хорошую успеваемость в вузе, то уровня его знаний должно хватить для успешного прохождения отбора.',
#  'Да, ведутся записи лекций онлайн, которые доступны только для студентов проекта на портале и в чатах соответствующих курсов. Видео курсов, которые читались в разное время в ОЦ и других образовательных проектах компании, размещены на каналеVK Teamв общем доступе.',
#  'Балльно-рейтинговая система. Рейтинг — это сумма баллов при сдаче контрольных точек, набранная студентом в течение семестра. Для успешного перевода на следующий семестр необходимо набрать пороговый рейтинг — минимальное количество баллов, установленное преподавателями по каждой дисциплине. Разбалловка по курсу доносится на первом занятии. Кроме того, преподаватель объясняет вес каждого рубежного контроля, задачи или проекта в общем балле, который может набрать студент. С 2021 года действует гибкая система обучения, позволяющая раньше заканчивать проект. Диплом выдаётся только после окончания четырёх семестров по  программе веб-разработки, трёх — для  программы по машинному обучению и двух семестров по мобильной разработке на IOS или Android.',
#  'Нет, но студенты обязаны сдать контрольные точки и набрать определённое количество баллов для перехода на следующий семестр. Если студент не сдал хотя бы один из курсов, он отчисляется из проекта.',
#  'Обучение в Центре построено на гибридном формате. Полностью удалённое обучение невозможно, так как содержание дисциплин изменяется каждый семестр и просмотра видеозаписей недостаточно для полноценного освоения курса. Также преподаватель не сможет объективно оценить студента без личного общения.Студент может посещать только те курсы, которые входят в программу его обучения в конкретном семестре. Студенты, не прошедшие отбор, не допускаются к обучению в Центре.',
#  'Студенты могут задавать вопросы преподавателям по нескольким каналам:- на очных занятиях в ходе лекций и семинаров ;- в блоге дисциплин на портале ОЦ (комментарии к посту о занятии, например);- в личных сообщениях на портале;- в чате дисциплины в VK;- письмом на личную почту преподавателя.',
#  'В последнем семестре разрабатывают итоговый командный проект, где необходимо продемонстрировать знания и навыки, полученные за время обучения. Это возможность пополнить портфолио сложной и интересной работой. Проект увидит и оценит экспертное жюри из числа топ-менеджеров VK.',
#  'Примерно 18 академических часов в неделю, из которых 12 — аудиторные (3-4 занятия). Достаточно много времени занимает работа над проектами в команде.',
#  'Набор на основную программу обучения проходит два раза в год: в сентябре и феврале - он связан с началом семестров в вузе.',
#  'В первом семестре для решения практических заданий активно используется C++ и Python, а также парадигма объектно-ориентированного программирования.',
#  'Отбор проходит в два этапа: онлайн-тестирование и очное собеседование с преподавателями, включающее мотивационную часть и решение задач.',
#  'Если студент успешно проходит первый отборочный этап ( тестирование online), его приглашают на второй - очное собеседование с преподавателями проекта.На почту приходит письмо-приглашение с открытыми слотами для собеседования и кейсом, который является частью очного собеседования и к которому нужно подготовиться заранее.Место проведения: МГТУ им. Н. Э. Баумана , длительность собеседования -  35-40 минут.Собеседование состоит из трёх частей:- задания на чтение кода,- задания на написание кода,- решение кейса. Последний получают на почту после успешного прохождения тестирования для предварительной подготовки. На собеседовании студентам потребуется прокомментировать ход решения кейса и ответить на вопросы эксперта. Задание кейса будет направлено на почту после успешного прохождения тестирования.В течение трёх рабочих дней после собеседованияна почту придёт письмо с приглашением на организационное собрание для зачисленных и с отказом для тех, кто не прошёл отбор.',
#  'Для регитстрации на отбор необходимо:1. Подробно заполнить анкету абитуриента, указывая актуальные телефон и почту.В анкете  необходимо указывать курс  и группу вуза, на который вы перешли (для старта набора в августе) или на котором учитесь (для старта набора в январе!2. Выбрать программу или курс в личном кабинете.3.Получать уведомления о начале отбора, его этапах, результатах на указанную при регистрации почту. 4.Следить за информацией о ходе отборана порталеив группе в VK.',
#  'Убедиться в том, что ты проверяешь почтовый адрес, который был указан при регистрации на проект. Проверить папку «Спам» — письмо могло попасть в неё.Если на почте ссылки нет, то её можно найти в своём личном кабинете. Для этого переходи на портал проекта и ищи кнопку «К испытанию». Она будет в блоке с программой, на которую подана заявка.Если возникнут технические вопросы, пиши в поддержку: info@park.vk.company',
#  'Мы проводим организационное собрание для тех, кто поступил на один из треков основной программы, на котором рассказываем студентам о проекте, отвечаем на вопросы и выдаём подарочный мерч.Для 1 семестра осеннего набора обучение начинается ориентировочно с 1 октября, для весеннего набора - с 1 марта. Весь сентябрь и февраль проходят промо наборов и отборочные испытания.',
#  'Диплом об окончании курса, который даёт 15 дополнительных баллов при поступлении в магистратуру МГТУ.',
#  'Отбор проходит в виде тестирования и мотивационного письма, которое имеет большой вес при принятии решения о зачислении. Набор осуществляется два раза в год: обычно в сентябре и  феврале. Но время набора может меняться, следить за анонсами запуска курсов можно вгруппе VK.',
#  'Обычно от четырёх академических часов в неделю без учёта времени на домашние задания. Но нагрузка на каждой программе может быть разной. .',
#  'Да, на семестровые курсы существует отбор в виде тестирования, так как конкурс достаточно большой. По окончании обучения экзаменов нет, но есть баллы за контрольные мероприятия, по сумме которых выставляются итоговые оценки. По итогам обучения выдается сертификат об окончании курса, который дает 5 дополнительных баллов при поступлении в магистратуру МГТУ.',
#  'Баллы и оценки заносятся в сертификат об окончании курса, который даёт пять дополнительных баллов при поступлении в магистратуру МГТУ.',
#  'На некоторых курсах могут обучаться не только студенты МГТУ, но и студенты других российских или московских вузов. Поэтому для подачи заявки, прохождения отбора и обучения необходимо зарегистрироваться напортале VK Образованияи насайте ОЦ.',
